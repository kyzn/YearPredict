# %% [markdown]
# # (1) ANN, no hidden layers, 90 years

# %%
import loader
import network2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

training_data, test_data = loader.load_data_wrapper()

# %%
#30 epoch of Shallow NN - 90 years

reload(network2)
net = network2.Network([90,90], cost=network2.CrossEntropyCost) 
net.large_weight_initializer()
net.SGD(training_data, test_data, epochs=30, eta=0.5, lmbda=0.1)
# Out:
# epoch, diff, sqdiff, accuracy
# 0 0.408360799001 0.516340636939 0.130666666667
# 1 0.34409113608 0.457935665475 0.154222222222
# 2 0.379630461923 0.492070524076 0.147555555556
# 3 0.372146067416 0.489260657202 0.152888888889
# 4 0.307721598003 0.423307919212 0.132666666667
# 5 0.251207240949 0.355035852545 0.148333333333
# 6 0.181234706617 0.251458928121 0.169666666667
# 7 0.214583021223 0.29677230026 0.144444444444
# 8 0.301370786517 0.413412508215 0.158777777778
# 9 0.259012484395 0.374705521525 0.177111111111
# 10 0.401106117353 0.514426531312 0.161333333333
# 11 0.207253433208 0.29736799386 0.155888888889
# 12 0.194096129838 0.280288049973 0.167555555556
# 13 0.345524344569 0.46416443704 0.178222222222
# 14 0.279390761548 0.396191912504 0.168777777778
# 15 0.223917602996 0.32782529991 0.194888888889
# 16 0.194700374532 0.274157942939 0.156666666667
# 17 0.209282147316 0.301551371296 0.147555555556
# 18 0.329699126092 0.437569776289 0.157666666667
# 19 0.282960049938 0.402162773 0.175666666667
# 20 0.210981273408 0.307901617169 0.165888888889
# 21 0.395239700375 0.508937707752 0.161
# 22 0.230033707865 0.327939677105 0.178111111111
# 23 0.324544319601 0.437041132704 0.158888888889
# 24 0.263870162297 0.382138962925 0.183
# 25 0.401779026217 0.512228707804 0.165222222222
# 26 0.20436329588 0.305697761672 0.172666666667
# 27 0.298734082397 0.421014732704 0.185333333333
# 28 0.205519350811 0.306291873786 0.182333333333
# 29 0.284489388265 0.408524073721 0.188

# %% [markdown]
# # (2) Deep NN, 90 years

# %%
#30 epoch of Deep NN - 90 years

reload(network2)
net = network2.Network([90,30,90], cost=network2.CrossEntropyCost) 
net.large_weight_initializer()
net.SGD(training_data, test_data, epochs=30, eta=0.5, lmbda=0.1)
# Out:
# epoch, diff, sqdiff, accuracy
# 0 0.273112359551 0.327577991543 0.0116666666667
# 1 0.250126092385 0.288962828153 0.0108888888889
# 2 0.450156054931 0.532252342084 0.0117777777778
# 3 0.266765293383 0.317560173956 0.011
# 4 0.253548064919 0.29465683678 0.0108888888889
# 5 0.298335830212 0.364346544353 0.0125555555556
# 6 0.253380774032 0.294369347203 0.0108888888889
# 7 0.337112359551 0.412255495143 0.0105555555556
# 8 0.361689138577 0.441915554608 0.0113333333333
# 9 0.485530586767 0.56456159098 0.0114444444444
# 10 0.444265917603 0.526604613031 0.011
# 11 0.26102372035 0.30656042723 0.0107777777778
# 12 0.309016229713 0.378543348324 0.013
# 13 0.406730337079 0.489456295114 0.00977777777778
# 14 0.252601747815 0.293826991995 0.0101111111111
# 15 0.276138576779 0.329900026811 0.0102222222222
# 16 0.303536828964 0.371363697857 0.0128888888889
# 17 0.273144818976 0.327617599117 0.0116666666667
# 18 0.261332084894 0.308784247377 0.00766666666667
# 19 0.394222222222 0.476952314996 0.011
# 20 0.354244694132 0.433501823717 0.0111111111111
# 21 0.430546816479 0.513458886977 0.0102222222222
# 22 0.412001248439 0.495156059023 0.012
# 23 0.474906367041 0.555028354547 0.0122222222222
# 24 0.263966292135 0.313047791702 0.0123333333333
# 25 0.347207240949 0.425340933527 0.0111111111111
# 26 0.254887640449 0.296846404994 0.012
# 27 0.261322097378 0.308769074097 0.00766666666667
# 28 0.50320474407 0.580068142604 0.0117777777778
# 29 0.293400749064 0.357556620024 0.0135555555556
